# %%
import pydicom
from pydicom.dataset import Dataset, FileDataset
from pydicom.uid import generate_uid
import os
import matplotlib.pylab as plt
import numpy as np
#import cv2
from skimage import exposure

# %%
# Step 1: Load the DICOM image

file_names=[]
directory = '../../RadiomiK/Immagini/RADIOMIK_GE/RAD_GE/SHAPE_43/'
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    if os.path.isfile(f) and filename.endswith('.dcm'):
        file_names.append(f)

print(len(file_names))
#print(file_names[10])
print(file_names)

dicom_image = pydicom.dcmread(file_names[0])  
print(file_names[0])
# Step 2: Extract relevant image information

pixel_array = dicom_image.pixel_array
print(pixel_array.shape)

slice_select = 21 #cambire slice a seconda della shape dell'immagine: 10

pixelarray_slice=pixel_array[slice_select,:,:]   #FINCHE' LA SLICE THICKNESS è LA STESSA, DOVREBBE RIMANERE UGUALE (-1 rispetto a quella di imagej)
#Print max and min values of the pixel array
print(np.max(pixel_array))
print(np.min(pixel_array))

spacing = dicom_image.PixelSpacing
print(spacing)
z_dim = dicom_image.NumberOfFrames
print(z_dim)
# retrive the slice thickness, assuming all slices are the same
slice_thickness = dicom_image.SliceThickness
print(slice_thickness)

plt.imshow(pixelarray_slice, cmap='gray')
plt.show()
# Out:
# 3
# ['../../../RadiomiK/Immagini/RADIOMIK_GE/RAD_GE/SHAPE_43/RAD_GE_LUNG_7_FBP_1.dcm', '../../../RadiomiK/Immagini/RADIOMIK_GE/RAD_GE/SHAPE_43/RAD_GE_LUNG_7_FBP_3.dcm', '../../../RadiomiK/Immagini/RADIOMIK_GE/RAD_GE/SHAPE_43/RAD_GE_LUNG_7_FBP_2.dcm']
# ../../../RadiomiK/Immagini/RADIOMIK_GE/RAD_GE/SHAPE_43/RAD_GE_LUNG_7_FBP_1.dcm
# (43, 512, 512)
# 36863
# 30768
# [0.703125, 0.703125]
# 43
# 1.25

# %%
#Equalize the  2D image histogram
# Setting the medium value to the mean of the image and the windows width to 3 times the standard deviation

display_min = np.mean(pixelarray_slice) - 3*np.std(pixelarray_slice)
display_max = np.mean(pixelarray_slice) + 3*np.std(pixelarray_slice)

# Clip the image values to the display range
dicom_image_clipped = np.clip(pixelarray_slice, display_min, display_max)

plt.imshow(dicom_image_clipped, cmap='gray')
plt.show()

# Normalize the clipped image to the [0, 1] range
dicom_image_normalized = (dicom_image_clipped - display_min) / (display_max - display_min)
dicom_image_equalized = exposure.equalize_hist(dicom_image_normalized)

# Display the normalized image using 'gray' colormap
plt.imshow(dicom_image_equalized, cmap='gray')
plt.show()

# %%
#ROI definitions
#posizioni del TOSHIBA
#Cylindrical ROI

center_y = [171, 214, 256, 299]  
center_x = [304, 304, 304, 304]
center_x=np.array(center_x)
center_y=np.array(center_y)



'''
#Cylindrical ROI GE dose 4
center_y = [225, 256, 286, 317]
center_x = [291, 291, 290, 290]
'''

center_z = slice_select  
radius = 9  #da verificare
height = 4   #da verificare

#Rectangular ROI
center_x_rect_GE = [171, 213, 256, 298, 341, 86, 128, 170, 213, 256, 299, 342, 385, 427, 343] 
center_y_rect_GE = [206, 206, 206, 206, 206, 257, 256, 256, 256, 256, 255, 255, 254, 254, 304] 
center_x_rect_GE=np.array(center_x_rect_GE)
center_y_rect_GE=np.array(center_y_rect_GE)


'''
#Rectangular ROI GE dose 4
center_x_rect_GE = [225, 256, 286, 317, 347, 86, 117, 147, 178, 208, 239, 269, 300, 330, 361]
center_y_rect_GE = [220, 220, 220, 220, 291, 257, 256, 256, 256, 256, 255, 254, 254, 254, 291]
''' 

width = 9

'''
#Test1
center_x=center_x + 1 
center_x_rect_GE=center_x_rect_GE + 1


#Test2
center_x=center_x -1
center_x_rect_GE=center_x_rect_GE - 1

#Test3
center_y=center_y + 1
center_y_rect_GE=center_y_rect_GE + 1

#Test4
center_y=center_y - 1
center_y_rect_GE=center_y_rect_GE - 1

#Test5
center_z=center_z + 1

#Test6
center_z=center_z - 1

#Test7
center_x=center_x + 1
center_x_rect_GE=center_x_rect_GE + 1
center_z=center_z + 1

#Test8
center_x=center_x - 1
center_x_rect_GE=center_x_rect_GE - 1
center_z=center_z - 1

#Test9
center_y=center_y + 1
center_y_rect_GE=center_y_rect_GE + 1
center_z=center_z + 1

#Test10
center_y=center_y - 1
center_y_rect_GE=center_y_rect_GE - 1
center_z=center_z - 1
'''

# Create a binary mask for cylindrical ROI
maschere=[]

for k, j in zip(center_x, center_y):
    print(k)
    print(j)
    mask3D = np.zeros_like(dicom_image.pixel_array).astype('uint16')

    for i in range (mask3D.shape[0]):
        if i >= center_z - height and i <= center_z + height:
            x, y = np.ogrid[:pixelarray_slice.shape[0], :pixelarray_slice.shape[1]]
            mask3D[i,:,:][np.sqrt((x - k)**2 + (y - j)**2) <= radius] = 1
    print(mask3D.shape)
    maschere.append(mask3D)
        
mask3D_cyl0 = maschere[0]
mask3D_cyl1 = maschere[1]
mask3D_cyl2 = maschere[2]
mask3D_cyl3 = maschere[3]

# Create a binary mask for rectangular ROI
maschere_rect=[]

for k, j in zip(center_x_rect_GE, center_y_rect_GE):
    print(k)
    print(j)
    mask3D_rect = np.zeros_like(dicom_image.pixel_array).astype('uint16')

    for i in range (mask3D_rect.shape[0]):
        if i >= center_z - height and i <= center_z + height:
            mask3D_rect[i,:,:][j-width:j+width, k-width:k+width] = 1
    print(mask3D_rect.shape)
    maschere_rect.append(mask3D_rect)

mask3D_rect0 = maschere_rect[0]
mask3D_rect1 = maschere_rect[1]
mask3D_rect2 = maschere_rect[2]
mask3D_rect3 = maschere_rect[3]
mask3D_rect4 = maschere_rect[4]
mask3D_rect5 = maschere_rect[5]
mask3D_rect6 = maschere_rect[6]
mask3D_rect7 = maschere_rect[7]
mask3D_rect8 = maschere_rect[8]
mask3D_rect9 = maschere_rect[9]
mask3D_rect10 = maschere_rect[10]
mask3D_rect11 = maschere_rect[11]
mask3D_rect12 = maschere_rect[12]
mask3D_rect13 = maschere_rect[13]
mask3D_rect14 = maschere_rect[14]
# Out:
# 304
# 171
# (43, 512, 512)
# 304
# 214
# (43, 512, 512)
# 304
# 256
# (43, 512, 512)
# 304
# 299
# (43, 512, 512)
# 171
# 206
# (43, 512, 512)
# 213
# 206
# (43, 512, 512)
# 256
# 206
# (43, 512, 512)
# 298
# 206
# (43, 512, 512)
# 341
# 206
# (43, 512, 512)
# 86
# 257
# (43, 512, 512)
# 128
# 256
# (43, 512, 512)
# 170
# 256
# (43, 512, 512)
# 213
# 256
# (43, 512, 512)
# 256
# 256
# (43, 512, 512)
# 299
# 255
# (43, 512, 512)
# 342
# 255
# (43, 512, 512)
# 385
# 254
# (43, 512, 512)
# 427
# 254
# (43, 512, 512)
# 343
# 304
# (43, 512, 512)

# %%
# Create a binary mask for_tipologiaangular ROI
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
center_z = slice_select  

width_3 = 110
height = 20

width_4 = 190

width_5 = 110

width_6 = 40

width_7 = 15




#Rectangular ROI
tipologia_3_x = 256
tipologia_3_y = 206 

tipologia_4_x = 256
tipologia_4_y = 256

tipologia_5_x = 256
tipologia_5_y = 306

tipologia_6_x = 240
tipologia_6_y = 350

tipologia_7_x = 300
tipologia_7_y = 350



tipologia_3= np.zeros_like(dicom_image.pixel_array).astype('uint16')
for i in range (tipologia_3.shape[0]):
        if i >= center_z - height and i <= center_z + height:
            tipologia_3[i,:,:][tipologia_3_y-height:tipologia_3_y+height, tipologia_3_x-width_3:tipologia_3_x+width_3] = 1

tipologia_4 = np.zeros_like(dicom_image.pixel_array).astype('uint16')
for i in range (tipologia_4.shape[0]):
        if i >= center_z - height and i <= center_z + height:
            tipologia_4[i,:,:][tipologia_4_y-height:tipologia_4_y+height, tipologia_4_x-width_4:tipologia_4_x+width_4] = 1

tipologia_5 = np.zeros_like(dicom_image.pixel_array).astype('uint16')
for i in range (tipologia_5.shape[0]):
        if i >= center_z - height and i <= center_z + height:
            tipologia_5[i,:,:][tipologia_5_y-height:tipologia_5_y+height, tipologia_5_x-width_5:tipologia_5_x+width_5] = 1

tipologia_6 = np.zeros_like(dicom_image.pixel_array).astype('uint16')
for i in range (tipologia_6.shape[0]):
        if i >= center_z - height and i <= center_z + height:
            tipologia_6[i,:,:][tipologia_6_y-height:tipologia_6_y+height, tipologia_6_x-width_6:tipologia_6_x+width_6] = 1

tipologia_7 = np.zeros_like(dicom_image.pixel_array).astype('uint16')
for i in range (tipologia_7.shape[0]):
        if i >= center_z - height and i <= center_z + height:
            tipologia_7[i,:,:][tipologia_7_y-height:tipologia_7_y+height, tipologia_7_x-width_7:tipologia_7_x+width_7] = 1

plt.imshow(dicom_image_equalized, cmap='gray')
plt.contour(tipologia_3[slice_select,:,:], [0.5], colors='cyan')
plt.contour(tipologia_4[slice_select,:,:], [0.5], colors='deepskyblue')
plt.contour(tipologia_5[slice_select,:,:], [0.5], colors='dodgerblue')
plt.contour(tipologia_6[slice_select,:,:], [0.5], colors='blue')
plt.contour(tipologia_7[slice_select,:,:], [0.5], colors='midnightblue')

# Crea gli oggetti Line2D per la legenda
line1 = mlines.Line2D([], [], color='cyan', label='Material PETG (5)')
line2 = mlines.Line2D([], [], color='deepskyblue', label='Material PLA (9)')
line3 = mlines.Line2D([], [], color='dodgerblue', label='Material FLEX (5)')
line4 = mlines.Line2D([], [], color='blue', label='Material homogeneous LUNG (2)')
line5 = mlines.Line2D([], [], color='midnightblue', label='Material homogeneous WATER (1)')
# Disegna dei triangoli sull'immagine
plt.scatter([170, 213, 256, 299, 342, 84, 127, 170, 213, 256, 299, 342, 385, 428, 170, 213, 256, 299, 342], [205, 205, 205, 205, 205, 256, 256, 256, 256, 255, 255, 255, 255, 255, 303, 303, 303, 303, 303], marker='^', s=120 , color=['gold','wheat', 'orange', 'darkgoldenrod', 'darkgoldenrod', 'gold', 'gold', 'wheat', 'wheat', 'orange', 'orange', 'darkgoldenrod', 'darkgoldenrod', 'darkgoldenrod', 'beige', 'wheat', 'darkgoldenrod', 'darkgoldenrod', 'darkgoldenrod'])

triangle0 = mlines.Line2D([], [], color='beige', marker='^', markersize=10, label='Pattern PARALLEL (1)', linestyle='None')
triangle3 = mlines.Line2D([], [], color='gold', marker='^', markersize=10, label='Pattern 1/4 CUBE (3)', linestyle='None')
triangle1 = mlines.Line2D([], [], color='wheat', marker='^', markersize=10, label='Pattern TRIESACUBE (4)', linestyle='None')
triangle2 = mlines.Line2D([], [], color='orange', marker='^', markersize=10, label='Pattern TRIANGLE (3)', linestyle='None')
triangle4 = mlines.Line2D([], [], color='goldenrod', marker='^', markersize=10, label='Pattern GYROID (8)', linestyle='None')

# Disegna dei numeri sull'immagine
plt.text(170, 185, '60', color='red', fontsize=10, ha='center', va='center')
plt.text(214, 185, '60', color='red', fontsize=10, ha='center', va='center')
plt.text(256, 185, '60', color='red', fontsize=10, ha='center', va='center')
plt.text(298, 185, '60', color='red', fontsize=10, ha='center', va='center')
plt.text(340, 185, '100', color='red', fontsize=10, ha='center', va='center')

plt.text(170, 222, 'Rect0', color='g', fontsize=10, ha='center', va='center')
plt.text(213, 222, 'Rect1', color='g', fontsize=10, ha='center', va='center')
plt.text(256, 222, 'Rect2', color='g', fontsize=10, ha='center', va='center')
plt.text(299, 222, 'Rect3', color='g', fontsize=10, ha='center', va='center')
plt.text(342, 222, 'Rect4', color='g', fontsize=10, ha='center', va='center')

plt.text(85, 234, '60', color='red', fontsize=10, ha='center', va='center')
plt.text(127, 234, '60', color='red', fontsize=10, ha='center', va='center')
plt.text(169, 234, '20', color='red', fontsize=10, ha='center', va='center')
plt.text(212, 234, '60', color='red', fontsize=10, ha='center', va='center')
plt.text(255, 234, '20', color='red', fontsize=10, ha='center', va='center')
plt.text(298, 234, '60', color='red', fontsize=10, ha='center', va='center')
plt.text(341, 234, '20', color='red', fontsize=10, ha='center', va='center')
plt.text(384, 234, '60', color='red', fontsize=10, ha='center', va='center')
plt.text(426, 234, '100', color='red', fontsize=10, ha='center', va='center')

plt.text(85, 274, 'Rect5', color='g', fontsize=10, ha='center', va='center')
plt.text(127, 274, 'Rect6', color='g', fontsize=10, ha='center', va='center')
plt.text(169, 274, 'Rect7', color='g', fontsize=10, ha='center', va='center')
plt.text(212, 274, 'Rect8', color='g', fontsize=10, ha='center', va='center')
plt.text(255, 274, 'Rect9', color='g', fontsize=10, ha='center', va='center')
plt.text(298, 274, 'Rect10', color='g', fontsize=10, ha='center', va='center')
plt.text(341, 274, 'Rect11', color='g', fontsize=10, ha='center', va='center')
plt.text(384, 274, 'Rect12', color='g', fontsize=10, ha='center', va='center')
plt.text(426, 274, 'Rect13', color='g', fontsize=10, ha='center', va='center')


plt.text(170, 283, '60', color='red', fontsize=10, ha='center', va='center')
plt.text(212, 283, '60', color='red', fontsize=10, ha='center', va='center')
plt.text(255, 283, '20', color='red', fontsize=10, ha='center', va='center')
plt.text(298, 283, '60', color='red', fontsize=10, ha='center', va='center')
plt.text(341, 283, '100', color='red', fontsize=10, ha='center', va='center')

plt.text(170, 323, 'Cyl0', color='g', fontsize=10, ha='center', va='center')
plt.text(212, 323, 'Cyl1', color='g', fontsize=10, ha='center', va='center')
plt.text(255, 323, 'Cyl2', color='g', fontsize=10, ha='center', va='center')
plt.text(298, 323, 'Cyl3', color='g', fontsize=10, ha='center', va='center')
plt.text(341, 323, 'Rect14', color='g', fontsize=10, ha='center', va='center')


# Aggiungi i triangoli alla legenda esistente
plt.legend(handles=[line1, line2, line3, line4, line5, triangle0, triangle1, triangle2, triangle3, triangle4], bbox_to_anchor=(1.02, 0.5), loc='center left')


plt.title('RadiomiK phantom')
plt.xlim(50, 460)
plt.ylim(420, 120)
plt.show()

# %%
#plot the contours of the ROIs on the image
plt.imshow(dicom_image_equalized, cmap='gray')
plt.contour(mask3D_cyl0[slice_select,:,:], [0.5], colors='r')
plt.contour(mask3D_cyl1[slice_select,:,:], [0.5], colors='r')
plt.contour(mask3D_cyl2[slice_select,:,:], [0.5], colors='r')
plt.contour(mask3D_cyl3[slice_select,:,:], [0.5], colors='r')
plt.contour(mask3D_rect0[slice_select,:,:], [0.5], colors='b')
plt.contour(mask3D_rect1[slice_select,:,:], [0.5], colors='b')
plt.contour(mask3D_rect2[slice_select,:,:], [0.5], colors='b')
plt.contour(mask3D_rect3[slice_select,:,:], [0.5], colors='b')
plt.contour(mask3D_rect4[slice_select,:,:], [0.5], colors='b')
plt.contour(mask3D_rect5[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect6[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect7[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect8[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect9[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect10[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect11[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect12[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect13[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect14[slice_select,:,:], [0.5], colors='g')
plt.title('Selected ROIs')
plt.xlim(50, 460)
plt.ylim(420, 120)
plt.show()

plt.imshow(pixelarray_slice, cmap='gray')
plt.contour(mask3D_cyl0[slice_select,:,:], [0.5], colors='r')
plt.contour(mask3D_cyl1[slice_select,:,:], [0.5], colors='r')
plt.contour(mask3D_cyl2[slice_select,:,:], [0.5], colors='r')
plt.contour(mask3D_cyl3[slice_select,:,:], [0.5], colors='r')
plt.contour(mask3D_rect0[slice_select,:,:], [0.5], colors='b')
plt.contour(mask3D_rect1[slice_select,:,:], [0.5], colors='b')
plt.contour(mask3D_rect2[slice_select,:,:], [0.5], colors='b')
plt.contour(mask3D_rect3[slice_select,:,:], [0.5], colors='b')
plt.contour(mask3D_rect4[slice_select,:,:], [0.5], colors='b')
plt.contour(mask3D_rect5[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect6[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect7[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect8[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect9[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect10[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect11[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect12[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect13[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect14[slice_select,:,:], [0.5], colors='g')
plt.title('Selected ROIs')
plt.xlim(50, 460)
plt.ylim(405, 120)
plt.show()

#plot the zoomed contours of the cylindrical ROI on the image
plt.imshow(pixelarray_slice, cmap='gray')
plt.contour(mask3D_cyl0[slice_select,:,:], [0.5], colors='r')
plt.contour(mask3D_cyl1[slice_select,:,:], [0.5], colors='r')
plt.contour(mask3D_cyl2[slice_select,:,:], [0.5], colors='r')
plt.contour(mask3D_cyl3[slice_select,:,:], [0.5], colors='r')
plt.contour(mask3D_rect14[slice_select,:,:], [0.5], colors='g')
plt.xlim(140, 360)
plt.ylim(280, 320)
plt.title('Cylindrical ROI')
plt.show()

#plot the contours of the cylindrical ROI on the image on the z axis
plt.imshow(pixel_array[:, 300, :], cmap='gray')
plt.contour(mask3D_cyl0[:,300,:], [0.5], colors='r')
plt.contour(mask3D_cyl1[:,300,:], [0.5], colors='r')
plt.contour(mask3D_cyl2[:,300,:], [0.5], colors='r')
plt.contour(mask3D_cyl3[:,300,:], [0.5], colors='r')
plt.contour(mask3D_rect14[:,300,:], [0.5], colors='g')
plt.title('Cylindrical ROI')
plt.xlim(150, 360)
plt.ylim(40, 10)
plt.show()

#plot the zoomed contours of the rectangular ROI on the image
plt.imshow(pixelarray_slice, cmap='gray')
plt.contour(mask3D_rect0[slice_select,:,:], [0.5], colors='b')
plt.contour(mask3D_rect1[slice_select,:,:], [0.5], colors='b')
plt.contour(mask3D_rect2[slice_select,:,:], [0.5], colors='b')
plt.contour(mask3D_rect3[slice_select,:,:], [0.5], colors='b')
plt.contour(mask3D_rect4[slice_select,:,:], [0.5], colors='b')
plt.xlim(120, 370)
plt.ylim(185, 225)
plt.title('Rectangular ROI first row')
plt.show()

#plot the contours of the rectangular ROI on the image on the z axis
plt.imshow(pixel_array[:, 211, :], cmap='gray')
plt.contour(mask3D_rect0[:,211,:], [0.5], colors='b')
plt.contour(mask3D_rect1[:,211,:], [0.5], colors='b')
plt.contour(mask3D_rect2[:,211,:], [0.5], colors='b')
plt.contour(mask3D_rect3[:,211,:], [0.5], colors='b')
plt.contour(mask3D_rect4[:,211,:], [0.5], colors='b')
plt.title('Rectangular ROI first row')
plt.xlim(150, 370)
plt.ylim(10, 40)
plt.show()

#plot the zoomed contours of the rectangular ROI on the image
plt.imshow(dicom_image_equalized, cmap='gray')
plt.contour(mask3D_rect5[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect6[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect7[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect8[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect9[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect10[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect11[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect12[slice_select,:,:], [0.5], colors='g')
plt.contour(mask3D_rect13[slice_select,:,:], [0.5], colors='g')
plt.xlim(65, 450)
plt.ylim(275, 230)
plt.title('Rectangular ROI second row')
plt.show()

#plot the contours of the rectangular ROI on the image on the z axis
plt.imshow(pixel_array[:, 256, :], cmap='gray')
plt.contour(mask3D_rect5[:,256,:], [0.5], colors='g')
plt.contour(mask3D_rect6[:,256,:], [0.5], colors='g')
plt.contour(mask3D_rect7[:,256,:], [0.5], colors='g')
plt.contour(mask3D_rect8[:,256,:], [0.5], colors='g')
plt.contour(mask3D_rect9[:,256,:], [0.5], colors='g')
plt.contour(mask3D_rect10[:,256,:], [0.5], colors='g')
plt.contour(mask3D_rect11[:,256,:], [0.5], colors='g')
plt.contour(mask3D_rect12[:,256,:], [0.5], colors='g')
plt.contour(mask3D_rect13[:,256,:], [0.5], colors='g')
plt.title('Rectangular ROI second row')
plt.xlim(50, 450)
plt.ylim(10, 40)
plt.show()

# %%
def create_dicom_from_array(mask, output_path, path):
    # Create a new DICOM dataset
    ds = FileDataset(output_path, {}, file_meta=dicom_image.file_meta, preamble=b'\0' * 128)
    ds.SOPClassUID = '1.2.840.10008.5.1.4.1.1.66' # DICOM SEG   #'1.2.840.10008.5.1.4.1.1.2'  # CT Image Storage
    ds.SOPInstanceUID = generate_uid()
    ds.file_meta = pydicom.Dataset()
    ds.FrameOfReferenceUID = dicom_image.FrameOfReferenceUID  
    ds.ImagePositionPatient = dicom_image.ImagePositionPatient
    ds.ImageOrientationPatient = dicom_image.ImageOrientationPatient

    # Set necessary metadata
    ds.PatientName = 'Anonymous'
    ds.PatientID = dicom_image.PatientID
    ds.Rows = mask.shape[1]
    ds.Columns = mask.shape[2]
    ds.PixelSpacing = dicom_image.PixelSpacing  # Define pixel spacing
    ds.SliceThickness = dicom_image.SliceThickness  # Define slice thickness
    ds.NumberOfFrames = mask.shape[0]
    ds.SamplesPerPixel = dicom_image.SamplesPerPixel # Set Samples Per Pixel
    ds.PhotometricInterpretation = 'MONOCHROME2'  # Set Photometric Interpretation
    ds.BitsAllocated = 16
    ds.BitsStored = 16
    ds.HighBit = 15
    ds.PixelRepresentation = 1  # Unsigned integer
    if hasattr(dicom_image, 'RotationDirection'):
        ds.RotationDirection = dicom_image.RotationDirection
    ds.PositionReferenceIndicator = dicom_image.PositionReferenceIndicator
    if hasattr(dicom_image, 'SliceLocation'):
        ds.SliceLocation = dicom_image.SliceLocation
    if hasattr(dicom_image, 'PatientPosition'):
        ds.PatientPosition = dicom_image.PatientPosition

    # Set pixel data
    ds.PixelData = mask.tobytes()
    
    ds.file_meta.TransferSyntaxUID = pydicom.uid.ImplicitVRLittleEndian
    # Save the DICOM file
    ds.save_as(path+output_path)

# %%
# Usage
maschere = [mask3D_cyl0, mask3D_cyl1, mask3D_cyl2, mask3D_cyl3, mask3D_rect0, mask3D_rect1, mask3D_rect2, mask3D_rect3, mask3D_rect4, mask3D_rect5, mask3D_rect6, mask3D_rect7, mask3D_rect8, mask3D_rect9, mask3D_rect10, mask3D_rect11, mask3D_rect12, mask3D_rect13, mask3D_rect14] 
output_path = ['mask_cyl0_GE.dcm', 'mask_cyl1_GE.dcm', 'mask_cyl2_GE.dcm', 'mask_cyl3_GE.dcm', 'mask_rect0_GE.dcm', 'mask_rect1_GE.dcm', 'mask_rect2_GE.dcm', 'mask_rect3_GE.dcm', 'mask_rect4_GE.dcm', 'mask_rect5_GE.dcm', 'mask_rect6_GE.dcm', 'mask_rect7_GE.dcm', 'mask_rect8_GE.dcm', 'mask_rect9_GE.dcm', 'mask_rect10_GE.dcm', 'mask_rect11_GE.dcm', 'mask_rect12_GE.dcm', 'mask_rect13_GE.dcm', 'mask_rect14_GE.dcm']
path = '../../../RadiomiK/Immagini/RADIOMIK_GE/RAD_GE_Volume_test_mask/Test_100/'  # Output path for the DICOM file

for mask_name, output in zip (maschere, output_path):
    
    create_dicom_from_array(mask_name, output, path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 8
#       4 path = '../../../../RadiomiK/Immagini/RADIOMIK_GE/RAD_GE_Volume_test_mask/Test_100/'  # Output path for the DICOM file
#       6 for mask_name, output in zip (maschere, output_path):
# ----> 8     create_dicom_from_array(mask_name, output, path)
#
# Cell In[21], line 38, in create_dicom_from_array(mask, output_path, path)
#      36 ds.file_meta.TransferSyntaxUID = pydicom.uid.ImplicitVRLittleEndian
#      37 # Save the DICOM file
# ---> 38 ds.save_as(path+output_path)
#
# File ~/anaconda3/envs/Apple_tensorflow_env/lib/python3.10/site-packages/pydicom/dataset.py:2129, in Dataset.save_as(self, filename, write_like_original)
#    2114 def save_as(
#    2115     self,
#    2116     filename: Union[str, "os.PathLike[AnyStr]", BinaryIO],
#    2117     write_like_original: bool = True
#    2118 ) -> None:
#    2119     """Write the :class:`Dataset` to `filename`.
#    2120
#    2121     Wrapper for pydicom.filewriter.dcmwrite, passing this dataset to it.
#    (...)
#    2127         Write a DICOM file from a :class:`FileDataset` instance.
#    2128     """
# -> 2129     pydicom.dcmwrite(filename, self, write_like_original)
#
# File ~/anaconda3/envs/Apple_tensorflow_env/lib/python3.10/site-packages/pydicom/filewriter.py:1107, in dcmwrite(filename, dataset, write_like_original)
#    1105 filename = path_from_pathlike(filename)
#    1106 if isinstance(filename, str):
# -> 1107     fp = DicomFile(filename, 'wb')
#    1108     # caller provided a file name; we own the file handle
#    1109     caller_owns_file = False
#
# File ~/anaconda3/envs/Apple_tensorflow_env/lib/python3.10/site-packages/pydicom/filebase.py:212, in DicomFile(*args, **kwargs)
#     211 def DicomFile(*args: Any, **kwargs: Any) -> DicomFileLike:
# --> 212     return DicomFileLike(open(*args, **kwargs))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../../../RadiomiK/Immagini/RADIOMIK_GE/RAD_GE_Volume_test_mask/Test_100/mask_cyl0_GE.dcm'
