# %%
#Load csv files into a pandas dataframe

import pandas as pd
import pingouin as pg
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import statsmodels.api as sm

# %%
#Read in the csv file
#Load csv file into dataframe
df_1 = pd.read_csv('../../../RadiomiK/Filtered_features/Test_ReTest/Cyl0_filtered_features_test.csv')
df_1

#Add a new column 'Protocol_new' to the dataframe: if Protocol is 'Protocol_1' then Protocol_new is 1, if Protocol is 'Protocol_2' then Protocol_new is 2 and so on
df_1['Protocol_numb'] = df_1['Protocol'].str.extract('(\d+)', expand=False).astype(int)

#Add a new column 'Insert' to the dataframe in witch the value is 'cyl0' for all rows
df_1['Insert'] = 'cyl0'
df_1
# Out:
#                                                Feature     Protocol  CV_Value  \
# 0               original_firstorder_InterquartileRange   Protocol_2  0.121660
# 1                         original_firstorder_Kurtosis   Protocol_2  0.172709
# 2            original_firstorder_MeanAbsoluteDeviation   Protocol_2  0.124558
# 3                            original_firstorder_Range   Protocol_2  0.213038
# 4      original_firstorder_RobustMeanAbsoluteDeviation   Protocol_2  0.142715
# ..                                                 ...          ...       ...
# 229       original_glszm_SmallAreaLowGrayLevelEmphasis  Protocol_14  0.277301
# 230                         original_glszm_ZoneEntropy  Protocol_14  0.151553
# 231  original_gldm_LargeDependenceHighGrayLevelEmph...  Protocol_14  0.248076
# 232                 original_gldm_LowGrayLevelEmphasis  Protocol_14  0.204689
# 233  original_gldm_SmallDependenceLowGrayLevelEmphasis  Protocol_14  0.332884
#
#      Protocol_numb Insert
# ...

# %%
#Do the same for the other csv files

df_2 = pd.read_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Cyl1_filtered_features_test.csv')
df_2['Protocol_numb'] = df_2['Protocol'].str.extract('(\d+)', expand=False).astype(int)
df_2['Insert'] = 'cyl1'

df_3 = pd.read_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Cyl2_filtered_features_test.csv')
df_3['Protocol_numb'] = df_3['Protocol'].str.extract('(\d+)', expand=False).astype(int)
df_3['Insert'] = 'cyl2'

df_4 = pd.read_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Cyl3_filtered_features_test.csv')
df_4['Protocol_numb'] = df_4['Protocol'].str.extract('(\d+)', expand=False).astype(int)
df_4['Insert'] = 'cyl3'

df_5 = pd.read_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Rect0_filtered_features_test.csv')
df_5['Protocol_numb'] = df_5['Protocol'].str.extract('(\d+)', expand=False).astype(int)
df_5['Insert'] = 'rect0'

df_6 = pd.read_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Rect1_filtered_features_test.csv')
df_6['Protocol_numb'] = df_6['Protocol'].str.extract('(\d+)', expand=False).astype(int)
df_6['Insert'] = 'rect1'

df_7 = pd.read_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Rect2_filtered_features_test.csv')
df_7['Protocol_numb'] = df_7['Protocol'].str.extract('(\d+)', expand=False).astype(int)
df_7['Insert'] = 'rect2'

df_8 = pd.read_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Rect3_filtered_features_test.csv')
df_8['Protocol_numb'] = df_8['Protocol'].str.extract('(\d+)', expand=False).astype(int)
df_8['Insert'] = 'rect3'

df_9 = pd.read_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Rect4_filtered_features_test.csv')
df_9['Protocol_numb'] = df_9['Protocol'].str.extract('(\d+)', expand=False).astype(int)
df_9['Insert'] = 'rect4'

df_10 = pd.read_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Rect5_filtered_features_test.csv')
df_10['Protocol_numb'] = df_10['Protocol'].str.extract('(\d+)', expand=False).astype(int)
df_10['Insert'] = 'rect5'

df_11 = pd.read_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Rect6_filtered_features_test.csv')
df_11['Protocol_numb'] = df_11['Protocol'].str.extract('(\d+)', expand=False).astype(int)
df_11['Insert'] = 'rect6'

df_12 = pd.read_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Rect7_filtered_features_test.csv')
df_12['Protocol_numb'] = df_12['Protocol'].str.extract('(\d+)', expand=False).astype(int)
df_12['Insert'] = 'rect7'

df_13 = pd.read_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Rect8_filtered_features_test.csv')
df_13['Protocol_numb'] = df_13['Protocol'].str.extract('(\d+)', expand=False).astype(int)
df_13['Insert'] = 'rect8'

df_14 = pd.read_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Rect9_filtered_features_test.csv')
df_14['Protocol_numb'] = df_14['Protocol'].str.extract('(\d+)', expand=False).astype(int)
df_14['Insert'] = 'rect9'

df_15 = pd.read_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Rect10_filtered_features_test.csv')
df_15['Protocol_numb'] = df_15['Protocol'].str.extract('(\d+)', expand=False).astype(int)
df_15['Insert'] = 'rect10'

df_16 = pd.read_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Rect11_filtered_features_test.csv')
df_16['Protocol_numb'] = df_16['Protocol'].str.extract('(\d+)', expand=False).astype(int)
df_16['Insert'] = 'rect11'

df_17 = pd.read_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Rect12_filtered_features_test.csv')
df_17['Protocol_numb'] = df_17['Protocol'].str.extract('(\d+)', expand=False).astype(int)
df_17['Insert'] = 'rect12'

df_18 = pd.read_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Rect13_filtered_features_test.csv')
df_18['Protocol_numb'] = df_18['Protocol'].str.extract('(\d+)', expand=False).astype(int)
df_18['Insert'] = 'rect13'

df_19 = pd.read_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Rect14_filtered_features_test.csv')
df_19['Protocol_numb'] = df_19['Protocol'].str.extract('(\d+)', expand=False).astype(int)
df_19['Insert'] = 'rect14'

#concatenate all the dataframes into one
df_final=pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10, df_11, df_12, df_13, df_14, df_15, df_16, df_17, df_18, df_19], ignore_index=True)

df_final
# Out:
#                                                 Feature     Protocol  \
# 0                original_firstorder_InterquartileRange   Protocol_2
# 1                          original_firstorder_Kurtosis   Protocol_2
# 2             original_firstorder_MeanAbsoluteDeviation   Protocol_2
# 3                             original_firstorder_Range   Protocol_2
# 4       original_firstorder_RobustMeanAbsoluteDeviation   Protocol_2
# ...                                                 ...          ...
# 3874       original_glszm_SmallAreaLowGrayLevelEmphasis  Protocol_14
# 3875                         original_glszm_ZoneEntropy  Protocol_14
# 3876  original_gldm_LargeDependenceHighGrayLevelEmph...  Protocol_14
# 3877                 original_gldm_LowGrayLevelEmphasis  Protocol_14
# 3878  original_gldm_SmallDependenceLowGrayLevelEmphasis  Protocol_14
#
#       CV_Value  Protocol_numb  Insert
# 0     0.121660              2    cyl0
# 1     0.172709              2    cyl0
# ...

# %%
# Conta quante volte ciascuna caratteristica appare in 'filtered_features'
feature_counts = df_final['Feature'].value_counts()

# Visualizza i conteggi
feature_counts
# Out:
# Feature
# original_glcm_Idmn                                    170
# original_glcm_Idn                                     160
# original_gldm_SmallDependenceLowGrayLevelEmphasis     139
# original_glszm_SmallAreaLowGrayLevelEmphasis          135
# original_gldm_LargeDependenceHighGrayLevelEmphasis    123
#                                                      ...
# original_glcm_SumEntropy                                7
# original_glcm_Id                                        6
# original_firstorder_Entropy                             6
# original_glcm_JointEntropy                              5
# original_glrlm_RunLengthNonUniformity                   3
# Name: count, Length: 79, dtype: int64

# %%
#in totale abbiamo 14 protocolli (11 adesso) e 19 inserti per protocollo, quindi in totale di 266 (209 adesso) istanze
#vogliamo evidenziare quali feature hanno un CV maggiore del 10% il 50% delle volte (133 istanze su 266, 105 su 209)
#quindi vogliamo evidenziare le feature che hanno un CV maggiore del 10% in almeno 95 istanze su 190

#creiamo un dataframe con le feature che hanno un CV maggiore del 10% in almeno 95 istanze su 190
df_feature = feature_counts[feature_counts > 105]

# Visualizza i conteggi
df_feature
# Out:
# Feature
# original_glcm_Idmn                                    170
# original_glcm_Idn                                     160
# original_gldm_SmallDependenceLowGrayLevelEmphasis     139
# original_glszm_SmallAreaLowGrayLevelEmphasis          135
# original_gldm_LargeDependenceHighGrayLevelEmphasis    123
# original_glszm_SizeZoneNonUniformityNormalized        113
# original_glszm_ZoneEntropy                            107
# Name: count, dtype: int64

# %%
# Conta quante volte ciascuna caratteristica appare in 'df_1'
feature_counts_cyl0 = df_1['Feature'].value_counts()

# Visualizza i conteggi
feature_counts_cyl0

#creiamo un dataframe con le feature che hanno un CV maggiore del 10% in almeno 5 istanze su 11 (11 protocolli)
df_feature_cyl0 = feature_counts_cyl0[feature_counts_cyl0 > 5]

#save the dataframe in a csv file
df_feature_cyl0.to_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Final/Cyl0_testRetest.csv', index=True)

print('Features non ripetibili inserto Cyl0')
# Visualizza i conteggi
df_feature_cyl0
# Out:
# Features non ripetibili inserto Cyl0
# Feature
# original_gldm_SmallDependenceLowGrayLevelEmphasis     10
# original_glcm_Idmn                                    10
# original_glszm_SizeZoneNonUniformityNormalized         9
# original_gldm_LargeDependenceHighGrayLevelEmphasis     9
# original_glcm_Idn                                      9
# original_glcm_ClusterShade                             9
# original_glszm_SmallAreaEmphasis                       8
# original_firstorder_Skewness                           8
# original_firstorder_Kurtosis                           7
# original_glcm_Imc2                                     7
# original_glrlm_ShortRunLowGrayLevelEmphasis            7
# original_glrlm_LongRunLowGrayLevelEmphasis             6
# original_glcm_Imc1                                     6
# original_glrlm_LowGrayLevelRunEmphasis                 6
# original_glszm_SmallAreaLowGrayLevelEmphasis           6
# original_gldm_LowGrayLevelEmphasis                     6
# ...

# %%
# Conta quante volte ciascuna caratteristica appare in 'df_2'
feature_counts_cyl1 = df_2['Feature'].value_counts()

# Visualizza i conteggi
feature_counts_cyl1

#creiamo un dataframe con le feature che hanno un CV maggiore del 10% in almeno 5 istanze su 11 (11 protocolli)
df_feature_cyl1 = feature_counts_cyl1[feature_counts_cyl1 > 5]

#save the dataframe in a csv file
df_feature_cyl1.to_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Final/Cyl1_testRetest.csv', index=True)

print('Features non ripetibili inserto Cyl1')
# Visualizza i conteggi
df_feature_cyl1
# Out:
# Features non ripetibili inserto Cyl1
# Feature
# original_glszm_SmallAreaLowGrayLevelEmphasis         11
# original_gldm_SmallDependenceLowGrayLevelEmphasis     8
# Name: count, dtype: int64

# %%
# Conta quante volte ciascuna caratteristica appare in 'df_3'
feature_counts_cyl2 = df_3['Feature'].value_counts()

# Visualizza i conteggi
feature_counts_cyl2

#creiamo un dataframe con le feature che hanno un CV maggiore del 10% in almeno 5 istanze su 11 (11 protocolli)
df_feature_cyl2 = feature_counts_cyl2[feature_counts_cyl2 > 5]

#save the dataframe in a csv file
df_feature_cyl2.to_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Final/Cyl2_testRetest.csv', index=True)

print('Features non ripetibili inserto Cyl2')
# Visualizza i conteggi
df_feature_cyl2
# Out:
# Features non ripetibili inserto Cyl2
# Feature
# original_glcm_Idmn                                    11
# original_glcm_Idn                                     11
# original_firstorder_Kurtosis                           9
# original_glszm_LargeAreaHighGrayLevelEmphasis          9
# original_gldm_LargeDependenceHighGrayLevelEmphasis     7
# original_glszm_SmallAreaEmphasis                       7
# original_glszm_GrayLevelNonUniformity                  7
# original_glszm_SmallAreaLowGrayLevelEmphasis           7
# original_glszm_ZoneEntropy                             6
# original_gldm_SmallDependenceLowGrayLevelEmphasis      6
# original_glszm_SizeZoneNonUniformityNormalized         6
# Name: count, dtype: int64

# %%
# Conta quante volte ciascuna caratteristica appare in 'df_4'
feature_counts_cyl3 = df_4['Feature'].value_counts()

# Visualizza i conteggi
feature_counts_cyl3

#creiamo un dataframe con le feature che hanno un CV maggiore del 10% in almeno 5 istanze su 11 (11 protocolli)
df_feature_cyl3 = feature_counts_cyl3[feature_counts_cyl3 > 5]

#save the dataframe in a csv file
df_feature_cyl3.to_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Final/Cyl3_testRetest.csv', index=True)

print('Features non ripetibili inserto Cyl3')
# Visualizza i conteggi
df_feature_cyl3
# Out:
# Features non ripetibili inserto Cyl3
# Feature
# original_firstorder_Skewness                          11
# original_glcm_ClusterShade                            10
# original_gldm_LargeDependenceHighGrayLevelEmphasis    10
# original_firstorder_Kurtosis                          10
# original_glszm_SmallAreaEmphasis                       9
# original_glcm_Idn                                      9
# original_glcm_Idmn                                     9
# original_gldm_SmallDependenceLowGrayLevelEmphasis      9
# original_glszm_SizeZoneNonUniformityNormalized         9
# original_glszm_GrayLevelNonUniformity                  7
# original_gldm_DependenceEntropy                        7
# original_glcm_Imc2                                     6
# original_glrlm_ShortRunLowGrayLevelEmphasis            6
# original_glrlm_LowGrayLevelRunEmphasis                 6
# original_gldm_LowGrayLevelEmphasis                     6
# original_glcm_Correlation                              6
# ...

# %%
# Conta quante volte ciascuna caratteristica appare in 'df_5'
feature_counts_rect0 = df_5['Feature'].value_counts()

# Visualizza i conteggi
feature_counts_rect0

#creiamo un dataframe con le feature che hanno un CV maggiore del 10% in almeno 5 istanze su 11 (11 protocolli)
df_feature_rect0 = feature_counts_rect0[feature_counts_rect0 > 5]

#save the dataframe in a csv file
df_feature_rect0.to_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Final/Rect0_testRetest.csv', index=True)

print('Features non ripetibili inserto Rect0')
# Visualizza i conteggi
df_feature_rect0
# Out:
# Features non ripetibili inserto Rect0
# Feature
# original_glcm_Idmn                                    9
# original_firstorder_Range                             9
# original_glszm_LargeAreaHighGrayLevelEmphasis         8
# original_glcm_Idn                                     7
# original_firstorder_Kurtosis                          7
# original_gldm_DependenceEntropy                       6
# original_glszm_SmallAreaLowGrayLevelEmphasis          6
# original_glszm_SizeZoneNonUniformityNormalized        6
# original_gldm_LargeDependenceHighGrayLevelEmphasis    6
# Name: count, dtype: int64

# %%
# Conta quante volte ciascuna caratteristica appare in 'df_6'
feature_counts_rect1 = df_6['Feature'].value_counts()

# Visualizza i conteggi
feature_counts_rect1

#creiamo un dataframe con le feature che hanno un CV maggiore del 10% in almeno 5 istanze su 11 (11 protocolli)
df_feature_rect1 = feature_counts_rect1[feature_counts_rect1 > 5]

#save the dataframe in a csv file
df_feature_rect1.to_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Final/Rect1_testRetest.csv', index=True)

print('Features non ripetibili inserto Rect1')
# Visualizza i conteggi
df_feature_rect1
# Out:
# Features non ripetibili inserto Rect1
# Feature
# original_glcm_Idn                                  11
# original_glcm_Idmn                                 11
# original_firstorder_Maximum                         9
# original_firstorder_Kurtosis                        8
# original_glszm_SmallAreaEmphasis                    8
# original_glszm_SizeZoneNonUniformityNormalized      8
# original_glszm_SizeZoneNonUniformity                7
# original_gldm_SmallDependenceEmphasis               6
# original_gldm_DependenceNonUniformityNormalized     6
# original_glcm_Correlation                           6
# Name: count, dtype: int64

# %%
# Conta quante volte ciascuna caratteristica appare in 'df_7'
feature_counts_rect2 = df_7['Feature'].value_counts()

# Visualizza i conteggi
feature_counts_rect2

#creiamo un dataframe con le feature che hanno un CV maggiore del 10% in almeno 5 istanze su 11 (11 protocolli)
df_feature_rect2 = feature_counts_rect2[feature_counts_rect2 > 5]

#save the dataframe in a csv file
df_feature_rect2.to_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Final/Rect2_testRetest.csv', index=True)


print('Features non ripetibili inserto Rect2')
# Visualizza i conteggi
df_feature_rect2
# Out:
# Features non ripetibili inserto Rect2
# Feature
# original_glcm_Idmn                                    9
# original_glszm_SmallAreaLowGrayLevelEmphasis          8
# original_glcm_Idn                                     8
# original_glszm_LargeAreaHighGrayLevelEmphasis         7
# original_glszm_LowGrayLevelZoneEmphasis               7
# original_firstorder_Kurtosis                          6
# original_gldm_LargeDependenceHighGrayLevelEmphasis    6
# original_gldm_SmallDependenceLowGrayLevelEmphasis     6
# original_firstorder_Skewness                          6
# Name: count, dtype: int64

# %%
# Conta quante volte ciascuna caratteristica appare in 'df_8'
feature_counts_rect3 = df_8['Feature'].value_counts()

# Visualizza i conteggi
feature_counts_rect3

#creiamo un dataframe con le feature che hanno un CV maggiore del 10% in almeno 5 istanze su 11 (11 protocolli)
df_feature_rect3 = feature_counts_rect3[feature_counts_rect3 > 5]

#save the dataframe in a csv file
df_feature_rect3.to_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Final/Rect3_testRetest.csv', index=True)

print('Features non ripetibili inserto Rect3')
# Visualizza i conteggi
df_feature_rect3
# Out:
# Features non ripetibili inserto Rect3
# Feature
# original_glcm_Idmn                                    10
# original_gldm_LargeDependenceHighGrayLevelEmphasis    10
# original_gldm_DependenceEntropy                        9
# original_gldm_SmallDependenceLowGrayLevelEmphasis      9
# original_glcm_Idn                                      9
# original_glrlm_ShortRunLowGrayLevelEmphasis            8
# original_glszm_SmallAreaLowGrayLevelEmphasis           7
# original_gldm_LowGrayLevelEmphasis                     6
# original_glszm_SmallAreaEmphasis                       6
# original_glszm_SizeZoneNonUniformityNormalized         6
# original_glrlm_LowGrayLevelRunEmphasis                 6
# original_glcm_Imc2                                     6
# Name: count, dtype: int64

# %%
# Conta quante volte ciascuna caratteristica appare in 'df_9'
feature_counts_rect4 = df_9['Feature'].value_counts()

# Visualizza i conteggi
feature_counts_rect4

#creiamo un dataframe con le feature che hanno un CV maggiore del 10% in almeno 5 istanze su 11 (11 protocolli)
df_feature_rect4 = feature_counts_rect4[feature_counts_rect4 > 5]

#save the dataframe in a csv file
df_feature_rect4.to_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Final/Rect4_testRetest.csv', index=True)

print('Features non ripetibili inserto Rect4')
# Visualizza i conteggi
df_feature_rect4
# Out:
# Features non ripetibili inserto Rect4
# Feature
# original_glcm_ClusterShade                            11
# original_gldm_SmallDependenceLowGrayLevelEmphasis     10
# original_gldm_HighGrayLevelEmphasis                    9
# original_glrlm_LongRunHighGrayLevelEmphasis            9
# original_gldm_LargeDependenceHighGrayLevelEmphasis     9
# original_glcm_Idmn                                     9
# original_gldm_DependenceEntropy                        9
# original_glszm_SizeZoneNonUniformityNormalized         9
# original_glszm_HighGrayLevelZoneEmphasis               9
# original_glcm_Autocorrelation                          9
# original_glrlm_HighGrayLevelRunEmphasis                9
# original_glcm_JointAverage                             9
# original_glrlm_ShortRunHighGrayLevelEmphasis           8
# original_glszm_SmallAreaLowGrayLevelEmphasis           8
# original_glrlm_ShortRunLowGrayLevelEmphasis            8
# original_glszm_SmallAreaEmphasis                       8
# ...

# %%
# Conta quante volte ciascuna caratteristica appare in 'df_10'
feature_counts_rect5 = df_10['Feature'].value_counts()

# Visualizza i conteggi
feature_counts_rect5

#creiamo un dataframe con le feature che hanno un CV maggiore del 10% in almeno 5 istanze su 11 (11 protocolli)
df_feature_rect5 = feature_counts_rect5[feature_counts_rect5 > 5]

#save the dataframe in a csv file
df_feature_rect5.to_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Final/Rect5_testRetest.csv', index=True)

print('Features non ripetibili inserto Rect5')
# Visualizza i conteggi
df_feature_rect5
# Out:
# Features non ripetibili inserto Rect5
# Feature
# original_glszm_HighGrayLevelZoneEmphasis              9
# original_firstorder_Range                             9
# original_glszm_ZoneEntropy                            8
# original_glszm_SmallAreaHighGrayLevelEmphasis         8
# original_gldm_SmallDependenceHighGrayLevelEmphasis    8
# original_glrlm_ShortRunHighGrayLevelEmphasis          8
# original_firstorder_Skewness                          7
# original_gldm_LargeDependenceHighGrayLevelEmphasis    7
# original_gldm_DependenceEntropy                       7
# original_glrlm_HighGrayLevelRunEmphasis               7
# original_glcm_Imc2                                    7
# original_glcm_Idn                                     6
# original_glcm_Idmn                                    6
# original_glcm_JointAverage                            6
# original_glcm_Autocorrelation                         6
# original_glszm_SmallAreaEmphasis                      6
# ...

# %%
# Conta quante volte ciascuna caratteristica appare in 'df_11'
feature_counts_rect6 = df_11['Feature'].value_counts()

# Visualizza i conteggi
feature_counts_rect6

#creiamo un dataframe con le feature che hanno un CV maggiore del 10% in almeno 5 istanze su 11
df_feature_rect6 = feature_counts_rect6[feature_counts_rect6 > 5]

#save the dataframe in a csv file
df_feature_rect6.to_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Final/Rect6_testRetest.csv', index=True)

print('Features non ripetibili inserto Rect6')
# Visualizza i conteggi
df_feature_rect6
# Out:
# Features non ripetibili inserto Rect6
# Feature
# original_glszm_SmallAreaLowGrayLevelEmphasis          10
# original_glszm_SizeZoneNonUniformityNormalized        10
# original_glcm_Idn                                     10
# original_glcm_Idmn                                    10
# original_glszm_SmallAreaEmphasis                       9
# original_firstorder_Kurtosis                           9
# original_gldm_SmallDependenceLowGrayLevelEmphasis      8
# original_glszm_LargeAreaHighGrayLevelEmphasis          8
# original_glszm_ZoneEntropy                             8
# original_glszm_LowGrayLevelZoneEmphasis                8
# original_glcm_ClusterShade                             7
# original_gldm_SmallDependenceHighGrayLevelEmphasis     7
# original_firstorder_Skewness                           7
# original_glszm_HighGrayLevelZoneEmphasis               7
# original_gldm_DependenceVariance                       7
# original_glszm_SmallAreaHighGrayLevelEmphasis          7
# ...

# %%
# Conta quante volte ciascuna caratteristica appare in 'df_12'
feature_counts_rect7 = df_12['Feature'].value_counts()

# Visualizza i conteggi
feature_counts_rect7

#creiamo un dataframe con le feature che hanno un CV maggiore del 10% in almeno 5 istanze su 11
df_feature_rect7 = feature_counts_rect7[feature_counts_rect7 > 5]

#save the dataframe in a csv file
df_feature_rect7.to_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Final/Rect7_testRetest.csv', index=True)

print('Features non ripetibili inserto Rect7')
# Visualizza i conteggi
df_feature_rect7
# Out:
# Features non ripetibili inserto Rect7
# Feature
# original_glcm_Idmn                              10
# original_glszm_ZoneEntropy                       9
# original_glcm_Idn                                8
# original_glszm_SmallAreaLowGrayLevelEmphasis     6
# Name: count, dtype: int64

# %%
# Conta quante volte ciascuna caratteristica appare in 'df_13'
feature_counts_rect8 = df_13['Feature'].value_counts()

# Visualizza i conteggi
feature_counts_rect8

#creiamo un dataframe con le feature che hanno un CV maggiore del 10% in almeno 5 istanze su 11
df_feature_rect8 = feature_counts_rect8[feature_counts_rect8 > 5]

#save the dataframe in a csv file
df_feature_rect8.to_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Final/Rect8_testRetest.csv', index=True)

print('Features non ripetibili inserto Rect8')
# Visualizza i conteggi
df_feature_rect8
# Out:
# Features non ripetibili inserto Rect8
# Feature
# original_glcm_Idn                                    11
# original_glcm_Idmn                                    9
# original_glszm_SmallAreaLowGrayLevelEmphasis          8
# original_gldm_DependenceEntropy                       7
# original_gldm_SmallDependenceLowGrayLevelEmphasis     6
# Name: count, dtype: int64

# %%
# Conta quante volte ciascuna caratteristica appare in 'df_14'
feature_counts_rect9 = df_14['Feature'].value_counts()

# Visualizza i conteggi
feature_counts_rect9

#creiamo un dataframe con le feature che hanno un CV maggiore del 10% in almeno 5 istanze su 11
df_feature_rect9 = feature_counts_rect9[feature_counts_rect9 > 5]

#save the dataframe in a csv file
df_feature_rect9.to_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Final/Rect9_testRetest.csv', index=True)

print('Features non ripetibili inserto Rect9')
# Visualizza i conteggi
df_feature_rect9
# Out:
# Features non ripetibili inserto Rect9
# Feature
# original_glszm_ZoneEntropy                           10
# original_glszm_LargeAreaHighGrayLevelEmphasis         9
# original_gldm_DependenceEntropy                       7
# original_gldm_SmallDependenceLowGrayLevelEmphasis     7
# original_glszm_SmallAreaLowGrayLevelEmphasis          7
# original_firstorder_Kurtosis                          6
# Name: count, dtype: int64

# %%
# Conta quante volte ciascuna caratteristica appare in 'df_15'
feature_counts_rect10 = df_15['Feature'].value_counts()

# Visualizza i conteggi
feature_counts_rect10

#creiamo un dataframe con le feature che hanno un CV maggiore del 10% in almeno 5 istanze su 11
df_feature_rect10 = feature_counts_rect10[feature_counts_rect10 > 5]

#save the dataframe in a csv file
df_feature_rect10.to_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Final/Rect10_testRetest.csv', index=True)

print('Features non ripetibili inserto Rect10')
# Visualizza i conteggi
df_feature_rect10
# Out:
# Features non ripetibili inserto Rect10
# Feature
# original_glszm_SmallAreaLowGrayLevelEmphasis          11
# original_glcm_Idmn                                     9
# original_glcm_Idn                                      8
# original_gldm_SmallDependenceLowGrayLevelEmphasis      8
# original_glszm_LargeAreaHighGrayLevelEmphasis          7
# original_glszm_LowGrayLevelZoneEmphasis                7
# original_gldm_LargeDependenceHighGrayLevelEmphasis     6
# Name: count, dtype: int64

# %%
# Conta quante volte ciascuna caratteristica appare in 'df_16'
feature_counts_rect11 = df_16['Feature'].value_counts()

# Visualizza i conteggi
feature_counts_rect11

#creiamo un dataframe con le feature che hanno un CV maggiore del 10% in almeno 5 istanze su 11
df_feature_rect11 = feature_counts_rect11[feature_counts_rect11 > 5]

#save the dataframe in a csv file
df_feature_rect11.to_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Final/Rect11_testRetest.csv', index=True)

print('Features non ripetibili inserto Rect11')
# Visualizza i conteggi
df_feature_rect11
# Out:
# Features non ripetibili inserto Rect11
# Feature
# original_glcm_Idn                                     10
# original_glcm_Idmn                                    10
# original_glszm_ZoneEntropy                             8
# original_firstorder_Kurtosis                           8
# original_glszm_SmallAreaLowGrayLevelEmphasis           8
# original_glcm_Correlation                              8
# original_gldm_DependenceEntropy                        7
# original_firstorder_Range                              7
# original_glszm_LargeAreaHighGrayLevelEmphasis          7
# original_gldm_SmallDependenceLowGrayLevelEmphasis      7
# original_glrlm_HighGrayLevelRunEmphasis                6
# original_glszm_SizeZoneNonUniformityNormalized         6
# original_glszm_GrayLevelNonUniformity                  6
# original_glcm_Autocorrelation                          6
# original_glcm_JointAverage                             6
# original_glrlm_LongRunHighGrayLevelEmphasis            6
# ...

# %%
# Conta quante volte ciascuna caratteristica appare in 'df_17'
feature_counts_rect12 = df_17['Feature'].value_counts()

# Visualizza i conteggi
feature_counts_rect12

#creiamo un dataframe con le feature che hanno un CV maggiore del 10% in almeno 5 istanze su 11
df_feature_rect12 = feature_counts_rect12[feature_counts_rect12 > 5]

#save the dataframe in a csv file
df_feature_rect12.to_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Final/Rect12_testRetest.csv', index=True)

print('Features non ripetibili inserto Rect12')
# Visualizza i conteggi
df_feature_rect12
# Out:
# Features non ripetibili inserto Rect12
# Feature
# original_glszm_SizeZoneNonUniformityNormalized        10
# original_gldm_SmallDependenceLowGrayLevelEmphasis     10
# original_gldm_LargeDependenceHighGrayLevelEmphasis    10
# original_glcm_ClusterShade                             8
# original_glcm_Idmn                                     8
# original_glcm_Idn                                      8
# original_firstorder_Kurtosis                           7
# original_glszm_ZoneEntropy                             7
# original_glcm_JointAverage                             7
# original_glrlm_ShortRunLowGrayLevelEmphasis            7
# original_firstorder_Skewness                           7
# original_glszm_SmallAreaLowGrayLevelEmphasis           7
# original_glszm_SmallAreaEmphasis                       7
# original_glrlm_LowGrayLevelRunEmphasis                 6
# original_gldm_LowGrayLevelEmphasis                     6
# original_glszm_LowGrayLevelZoneEmphasis                6
# ...

# %%
# Conta quante volte ciascuna caratteristica appare in 'df_18'
feature_counts_rect13 = df_18['Feature'].value_counts()

# Visualizza i conteggi
feature_counts_rect13

#creiamo un dataframe con le feature che hanno un CV maggiore del 10% in almeno 5 istanze su 11
df_feature_rect13 = feature_counts_rect13[feature_counts_rect13 > 5]

#save the dataframe in a csv file
df_feature_rect13.to_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Final/Rect13_testRetest.csv', index=True)

print('Features non ripetibili inserto Rect13')
# Visualizza i conteggi
df_feature_rect13
# Out:
# Features non ripetibili inserto Rect13
# Feature
# original_glcm_Idmn                                    11
# original_gldm_SmallDependenceLowGrayLevelEmphasis     10
# original_gldm_LargeDependenceHighGrayLevelEmphasis    10
# original_glcm_ClusterShade                            10
# original_glcm_Idn                                     10
# original_firstorder_Kurtosis                           9
# original_glszm_SizeZoneNonUniformityNormalized         9
# original_glszm_GrayLevelNonUniformity                  9
# original_glszm_SmallAreaLowGrayLevelEmphasis           9
# original_glszm_SmallAreaEmphasis                       9
# original_glszm_LowGrayLevelZoneEmphasis                9
# original_firstorder_Skewness                           8
# original_glrlm_LongRunHighGrayLevelEmphasis            7
# original_gldm_HighGrayLevelEmphasis                    7
# original_glrlm_ShortRunLowGrayLevelEmphasis            7
# original_glrlm_HighGrayLevelRunEmphasis                7
# ...

# %%
# Conta quante volte ciascuna caratteristica appare in 'df_19'
feature_counts_rect14 = df_19['Feature'].value_counts()

# Visualizza i conteggi
feature_counts_rect14

#creiamo un dataframe con le feature che hanno un CV maggiore del 10% in almeno 5 istanze su 11
df_feature_rect14 = feature_counts_rect14[feature_counts_rect14 > 5]

#save the dataframe in a csv file
df_feature_rect14.to_csv('../../../../RadiomiK/Filtered_features/Test_ReTest/Final/Rect14_testRetest.csv', index=True)

print('Features non ripetibili inserto Rect14')
# Visualizza i conteggi
df_feature_rect14
# Out:
# Features non ripetibili inserto Rect14
# Feature
# original_gldm_SmallDependenceLowGrayLevelEmphasis     11
# original_glcm_Idn                                     11
# original_glcm_Idmn                                    11
# original_firstorder_Skewness                          11
# original_glcm_ClusterShade                            10
# original_gldm_LargeDependenceHighGrayLevelEmphasis     9
# original_glszm_SizeZoneNonUniformityNormalized         9
# original_glszm_SmallAreaEmphasis                       8
# original_firstorder_Kurtosis                           8
# original_glszm_GrayLevelNonUniformity                  6
# original_glcm_Imc2                                     6
# original_glszm_ZoneEntropy                             6
# Name: count, dtype: int64

# %%
#Add the column 'insert' to the dataframe df_feature_cyl0
df_feature_cyl0 = pd.DataFrame(df_feature_cyl0)
df_feature_cyl0['Insert'] = 'cyl0'
#add a column 'features' to the dataframe df_feature_cyl0
df_feature_cyl0['Features'] = df_feature_cyl0.index

#Add the column 'insert' to the dataframe df_feature_cyl1
df_feature_cyl1 = pd.DataFrame(df_feature_cyl1)
df_feature_cyl1['Insert'] = 'cyl1'
# add a column 'features' to the dataframe df_feature_cyl1
df_feature_cyl1['Features'] = df_feature_cyl1.index

#Add the column 'insert' to the dataframe df_feature_cyl2
df_feature_cyl2 = pd.DataFrame(df_feature_cyl2)
df_feature_cyl2['Insert'] = 'cyl2'
# add a column 'features' to the dataframe df_feature_cyl2
df_feature_cyl2['Features'] = df_feature_cyl2.index

#Add the column 'insert' to the dataframe df_feature_cyl3
df_feature_cyl3 = pd.DataFrame(df_feature_cyl3)
df_feature_cyl3['Insert'] = 'cyl3'
# add a column 'features' to the dataframe df_feature_cyl3
df_feature_cyl3['Features'] = df_feature_cyl3.index

#Add the column 'insert' to the dataframe df_feature_rect0
df_feature_rect0 = pd.DataFrame(df_feature_rect0)
df_feature_rect0['Insert'] = 'rect0_1R'
# add a column 'features' to the dataframe df_feature_rect0
df_feature_rect0['Features'] = df_feature_rect0.index

#Add the column 'insert' to the dataframe df_feature_rect1
df_feature_rect1 = pd.DataFrame(df_feature_rect1)
df_feature_rect1['Insert'] = 'rect1_1R'
# add a column 'features' to the dataframe df_feature_rect1
df_feature_rect1['Features'] = df_feature_rect1.index

#Add the column 'insert' to the dataframe df_feature_rect2
df_feature_rect2 = pd.DataFrame(df_feature_rect2)
df_feature_rect2['Insert'] = 'rect2_1R'
# add a column 'features' to the dataframe df_feature_rect2
df_feature_rect2['Features'] = df_feature_rect2.index

#Add the column 'insert' to the dataframe df_feature_rect3
df_feature_rect3 = pd.DataFrame(df_feature_rect3)
df_feature_rect3['Insert'] = 'rect3_1R'
# add a column 'features' to the dataframe df_feature_rect3
df_feature_rect3['Features'] = df_feature_rect3.index

#Add the column 'insert' to the dataframe df_feature_rect4
df_feature_rect4 = pd.DataFrame(df_feature_rect4)
df_feature_rect4['Insert'] = 'rect4_1R'
# add a column 'features' to the dataframe df_feature_rect4
df_feature_rect4['Features'] = df_feature_rect4.index

#Add the column 'insert' to the dataframe df_feature_rect5
df_feature_rect5 = pd.DataFrame(df_feature_rect5)
df_feature_rect5['Insert'] = 'rect5_2R'
# add a column 'features' to the dataframe df_feature_rect5
df_feature_rect5['Features'] = df_feature_rect5.index

#Add the column 'insert' to the dataframe df_feature_rect6
df_feature_rect6 = pd.DataFrame(df_feature_rect6)
df_feature_rect6['Insert'] = 'rect6_2R'
# add a column 'features' to the dataframe df_feature_rect6
df_feature_rect6['Features'] = df_feature_rect6.index

#Add the column 'insert' to the dataframe df_feature_rect7
df_feature_rect7 = pd.DataFrame(df_feature_rect7)
df_feature_rect7['Insert'] = 'rect7_2R'
# add a column 'features' to the dataframe df_feature_rect7
df_feature_rect7['Features'] = df_feature_rect7.index

#Add the column 'insert' to the dataframe df_feature_rect8
df_feature_rect8 = pd.DataFrame(df_feature_rect8)
df_feature_rect8['Insert'] = 'rect8_2R'
# add a column 'features' to the dataframe df_feature_rect8
df_feature_rect8['Features'] = df_feature_rect8.index

#Add the column 'insert' to the dataframe df_feature_rect9
df_feature_rect9 = pd.DataFrame(df_feature_rect9)
df_feature_rect9['Insert'] = 'rect9_2R'
# add a column 'features' to the dataframe df_feature_rect9
df_feature_rect9['Features'] = df_feature_rect9.index

#Add the column 'insert' to the dataframe df_feature_rect10
df_feature_rect10 = pd.DataFrame(df_feature_rect10)
df_feature_rect10['Insert'] = 'rect10_2R'
# add a column 'features' to the dataframe df_feature_rect10
df_feature_rect10['Features'] = df_feature_rect10.index

#Add the column 'insert' to the dataframe df_feature_rect11
df_feature_rect11 = pd.DataFrame(df_feature_rect11)
df_feature_rect11['Insert'] = 'rect11_2R'
# add a column 'features' to the dataframe df_feature_rect11
df_feature_rect11['Features'] = df_feature_rect11.index

#Add the column 'insert' to the dataframe df_feature_rect12
df_feature_rect12 = pd.DataFrame(df_feature_rect12)
df_feature_rect12['Insert'] = 'rect12_2R'
# add a column 'features' to the dataframe df_feature_rect12
df_feature_rect12['Features'] = df_feature_rect12.index

#Add the column 'insert' to the dataframe df_feature_rect13
df_feature_rect13 = pd.DataFrame(df_feature_rect13)
df_feature_rect13['Insert'] = 'rect13_2R'
# add a column 'features' to the dataframe df_feature_rect13
df_feature_rect13['Features'] = df_feature_rect13.index

#Add the column 'insert' to the dataframe df_feature_rect14
df_feature_rect14 = pd.DataFrame(df_feature_rect14)
df_feature_rect14['Insert'] = 'rect14_3R'
# add a column 'features' to the dataframe df_feature_rect14
df_feature_rect14['Features'] = df_feature_rect14.index

#Concatenate all the dataframes into one
df_feature_final=pd.concat([df_feature_cyl0, df_feature_cyl1, df_feature_cyl2, df_feature_cyl3, df_feature_rect0, df_feature_rect1, df_feature_rect2, df_feature_rect3, df_feature_rect4, df_feature_rect5, df_feature_rect6, df_feature_rect7, df_feature_rect8, df_feature_rect9, df_feature_rect10, df_feature_rect11, df_feature_rect12, df_feature_rect13, df_feature_rect14], ignore_index=True)


#Visualize the dataframe
df_feature_final

#Save the dataframe into a csv file
#df_feature_final.to_csv('../../../../Graphs and images/Radiomica/Features_non_ripetibili_test_retest.csv', index=False)
# Out:
#      count     Insert                                           Features
# 0       10       cyl0  original_gldm_SmallDependenceLowGrayLevelEmphasis
# 1       10       cyl0                                 original_glcm_Idmn
# 2        9       cyl0     original_glszm_SizeZoneNonUniformityNormalized
# 3        9       cyl0  original_gldm_LargeDependenceHighGrayLevelEmph...
# 4        9       cyl0                                  original_glcm_Idn
# ..     ...        ...                                                ...
# 245      8  rect14_3R                   original_glszm_SmallAreaEmphasis
# 246      8  rect14_3R                       original_firstorder_Kurtosis
# 247      6  rect14_3R              original_glszm_GrayLevelNonUniformity
# 248      6  rect14_3R                                 original_glcm_Imc2
# 249      6  rect14_3R                         original_glszm_ZoneEntropy
#
# [250 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Conta le occorrenze di ciascuna caratteristica
feature_counts = df_feature_final['Features'].value_counts()

# Crea un grafico a barre
plt.figure(figsize=(10, 6))
sns.barplot(x=feature_counts.index, y=feature_counts.values, palette="viridis")

plt.xlabel('Feature')
plt.ylabel('Count')
plt.title('Number of times each feature appears')
plt.xticks(rotation=90)  # Ruota le etichette x per una migliore leggibilità

plt.show()
# Out:
# /var/folders/gs/br7wczx17lz8kkw6qt2t83pr0000gn/T/ipykernel_1733/2565212722.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=feature_counts.index, y=feature_counts.values, palette="viridis")

# %%
import matplotlib.pyplot as plt

# Crea una tabella pivot con 'Feature' come indice, 'Insert' come colonne e conta le occorrenze
pivot_df = df_feature_final.pivot_table(index='Features', columns='Insert', aggfunc='size', fill_value=0)

# Crea un grafico a barre impilate
pivot_df.plot(kind='bar', stacked=True, figsize=(10, 6))

plt.xlabel('Feature')
plt.ylabel('Count')
plt.title('Number of times each feature appears, by insert')
plt.xticks(rotation=90)  # Ruota le etichette x per una migliore leggibilità

plt.show()

# %%
import matplotlib.pyplot as plt

# Ordina il DataFrame in base alla somma delle righe, dal più grande al più piccolo
pivot_df = pivot_df.reindex(pivot_df.sum(axis=1).sort_values(ascending=False).index)

# Crea un grafico a barre impilate
pivot_df.plot(kind='bar', stacked=True, figsize=(10, 6))

plt.xlabel('Feature')
plt.ylabel('Count')
plt.title('Number of times each feature appears, by insert')
plt.xticks(rotation=90)  # Ruota le etichette x per una migliore leggibilità
plt.legend(loc='upper right')  # Cambia la posizione della legenda

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

#Reorder the columns of the dataframe
pivot_df = pivot_df[['cyl0', 'cyl1', 'cyl2', 'cyl3', 'rect0_1R', 'rect1_1R', 'rect2_1R', 'rect3_1R', 'rect4_1R', 'rect5_2R', 'rect6_2R', 'rect7_2R', 'rect8_2R', 'rect9_2R', 'rect10_2R', 'rect11_2R', 'rect12_2R', 'rect13_2R', 'rect14_3R']]

#crea una colormap personalizzata in base al nome dell'inserto
color_map_insert = {
    'cyl0': plt.cm.Reds(0.3),
    'cyl1': plt.cm.Reds(0.5),
    'cyl2': plt.cm.Reds(0.7),
    'cyl3': plt.cm.Reds(0.9),
    'rect0_1R': plt.cm.Blues(0.3),
    'rect1_1R': plt.cm.Blues(0.5),
    'rect2_1R': plt.cm.Blues(0.7),
    'rect3_1R': plt.cm.Blues(0.9),
    'rect4_1R': plt.cm.Blues(1.1),
    'rect5_2R': plt.cm.Greens(0.3),
    'rect6_2R': plt.cm.Greens(0.5),
    'rect7_2R': plt.cm.Greens(0.7),
    'rect8_2R': plt.cm.Greens(0.9),
    'rect9_2R': plt.cm.Greens(1.1),
    'rect10_2R': plt.cm.Greys(0.25),
    'rect11_2R': plt.cm.Greys(0.4),
    'rect12_2R': plt.cm.Greys(0.6),
    'rect13_2R': plt.cm.Greys(0.8),
    'rect14_3R': plt.cm.Greys(1.0)
}


# Crea una lista di colori per ogni insert
#colors = plt.cm.Reds(np.linspace(0.3, 1, len(pivot_df.columns[pivot_df.columns.str.contains('cyl')])))
#colors = np.concatenate([colors, plt.cm.Blues(np.linspace(0.3, 1, len(pivot_df.columns[pivot_df.columns.str.contains('1R')])))])
#colors = np.concatenate([colors, plt.cm.Greens(np.linspace(0.3, 1, len(pivot_df.columns[pivot_df.columns.str.contains('2R')])))])
#colors = np.concatenate([colors, plt.cm.Greys(np.linspace(0.4, 1, len(pivot_df.columns[pivot_df.columns.str.contains('3R')])))])

colors = color_map_insert['cyl0'], color_map_insert['cyl1'], color_map_insert['cyl2'], color_map_insert['cyl3'], color_map_insert['rect0_1R'], color_map_insert['rect1_1R'], color_map_insert['rect2_1R'], color_map_insert['rect3_1R'], color_map_insert['rect4_1R'], color_map_insert['rect5_2R'], color_map_insert['rect6_2R'], color_map_insert['rect7_2R'], color_map_insert['rect8_2R'], color_map_insert['rect9_2R'], color_map_insert['rect10_2R'], color_map_insert['rect11_2R'], color_map_insert['rect12_2R'], color_map_insert['rect13_2R'], color_map_insert['rect14_3R']

# Crea un grafico a barre impilate con colori personalizzati
pivot_df.plot(kind='bar', stacked=True, figsize=(10, 6), color=colors)

plt.xlabel('Features')
plt.ylabel('Counts')
plt.title('Number of times each feature has CV > 10%, by insert')
plt.xticks(rotation=90)  # Ruota le etichette x per una migliore leggibilità
plt.legend(loc='upper right')  # Cambia la posizione della legenda

plt.show()

# %%
#print the name and number of feature that have CV > 10% in at least 5 instances for each insert
print('Features non ripetibili inserto Cyl0')
print(df_feature_cyl0)
print('Features non ripetibili inserto Cyl1')
print(df_feature_cyl1)
print('Features non ripetibili inserto Cyl2')
print(df_feature_cyl2)
print('Features non ripetibili inserto Cyl3')
print(df_feature_cyl3)
print('Features non ripetibili inserto Rect0')
print(df_feature_rect0)
print('Features non ripetibili inserto Rect1')
print(df_feature_rect1)
print('Features non ripetibili inserto Rect2')
print(df_feature_rect2)
print('Features non ripetibili inserto Rect3')
print(df_feature_rect3)
print('Features non ripetibili inserto Rect4')
print(df_feature_rect4)
print('Features non ripetibili inserto Rect5')
print(df_feature_rect5)
print('Features non ripetibili inserto Rect6')
print(df_feature_rect6)
print('Features non ripetibili inserto Rect7')
print(df_feature_rect7)
print('Features non ripetibili inserto Rect8')
print(df_feature_rect8)
print('Features non ripetibili inserto Rect9')
print(df_feature_rect9)
print('Features non ripetibili inserto Rect10')
print(df_feature_rect10)
print('Features non ripetibili inserto Rect11')
print(df_feature_rect11)
print('Features non ripetibili inserto Rect12')
print(df_feature_rect12)
print('Features non ripetibili inserto Rect13')
print(df_feature_rect13)
print('Features non ripetibili inserto Rect14')
print(df_feature_rect14)
# Out:
# Features non ripetibili inserto Cyl0
#                                                     count Insert  \
# Feature
# original_gldm_SmallDependenceLowGrayLevelEmphasis      10   cyl0
# original_glcm_Idmn                                     10   cyl0
# original_glszm_SizeZoneNonUniformityNormalized          9   cyl0
# original_gldm_LargeDependenceHighGrayLevelEmphasis      9   cyl0
# original_glcm_Idn                                       9   cyl0
# original_glcm_ClusterShade                              9   cyl0
# original_glszm_SmallAreaEmphasis                        8   cyl0
# original_firstorder_Skewness                            8   cyl0
# original_firstorder_Kurtosis                            7   cyl0
# original_glcm_Imc2                                      7   cyl0
# original_glrlm_ShortRunLowGrayLevelEmphasis             7   cyl0
# original_glrlm_LongRunLowGrayLevelEmphasis              6   cyl0
# original_glcm_Imc1                                      6   cyl0
# ...
