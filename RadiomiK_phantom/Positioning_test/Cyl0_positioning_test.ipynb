# %%
import pandas as pd
import pingouin as pg
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import statsmodels.api as sm

# %%
# Loding the TO csv file
df1 = pd.read_csv("../../../../RadiomiK/Features_Positioning_test/TO_test/Final/Test1/cyl0.csv")
df2 = pd.read_csv("../../../../RadiomiK/Features_Positioning_test/TO_test/Final/Test2/cyl0.csv")
df3 = pd.read_csv("../../../../RadiomiK/Features_Positioning_test/TO_test/Final/Test3/cyl0.csv")
df4 = pd.read_csv("../../../../RadiomiK/Features_Positioning_test/TO_test/Final/Test4/cyl0.csv")
df5 = pd.read_csv("../../../../RadiomiK/Features_Positioning_test/TO_test/Final/Test5/cyl0.csv")
df6 = pd.read_csv("../../../../RadiomiK/Features_Positioning_test/TO_test/Final/Test6/cyl0.csv")
df7 = pd.read_csv("../../../../RadiomiK/Features_Positioning_test/TO_test/Final/Test7/cyl0.csv")
df8 = pd.read_csv("../../../../RadiomiK/Features_Positioning_test/TO_test/Final/Test8/cyl0.csv")
df9 = pd.read_csv("../../../../RadiomiK/Features_Positioning_test/TO_test/Final/Test9/cyl0.csv")
df10 = pd.read_csv("../../../../RadiomiK/Features_Positioning_test/TO_test/Final/Test10/cyl0.csv")

# Concatenating the 10 csv files
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10])

#Elimino le colonne diagnostics
string_to_match = 'diagnostics'
filtered_columns = [col for col in df.columns if string_to_match not in col]
df = df[filtered_columns]
string_to_match = 'Unnamed:'
filtered_columns = [col for col in df.columns if string_to_match not in col]
df = df[filtered_columns]
df_TO = df
df_TO
# Out:
#    original_firstorder_10Percentile  original_firstorder_90Percentile  \
# 0                           32264.6                           32529.0
# 0                           32262.0                           32529.0
# 0                           32263.0                           32529.0
# 0                           32265.6                           32527.4
# 0                           32263.6                           32530.0
# 0                           32265.0                           32525.0
# 0                           32264.0                           32530.0
# 0                           32262.0                           32525.4
# 0                           32262.0                           32530.0
# 0                           32265.6                           32524.0
#
#    original_firstorder_Energy  original_firstorder_Entropy  \
# 0                2.274147e+12                     4.074692
# 0                2.273877e+12                     4.083260
# ...

# %%
# Loding the GE csv files and joining them in a single dataframe
df1 = pd.read_csv("../../../../RadiomiK/Features_Positioning_test/GE_test/Final/Test1/cyl0.csv")
df2 = pd.read_csv("../../../../RadiomiK/Features_Positioning_test/GE_test/Final/Test2/cyl0.csv")
df3 = pd.read_csv("../../../../RadiomiK/Features_Positioning_test/GE_test/Final/Test3/cyl0.csv")
df4 = pd.read_csv("../../../../RadiomiK/Features_Positioning_test/GE_test/Final/Test4/cyl0.csv")
df5 = pd.read_csv("../../../../RadiomiK/Features_Positioning_test/GE_test/Final/Test5/cyl0.csv")
df6 = pd.read_csv("../../../../RadiomiK/Features_Positioning_test/GE_test/Final/Test6/cyl0.csv")
df7 = pd.read_csv("../../../../RadiomiK/Features_Positioning_test/GE_test/Final/Test7/cyl0.csv")
df8 = pd.read_csv("../../../../RadiomiK/Features_Positioning_test/GE_test/Final/Test8/cyl0.csv")
df9 = pd.read_csv("../../../../RadiomiK/Features_Positioning_test/GE_test/Final/Test9/cyl0.csv")
df10 = pd.read_csv("../../../../RadiomiK/Features_Positioning_test/GE_test/Final/Test10/cyl0.csv")

df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10])

#Elimino le colonne diagnostics
string_to_match = 'diagnostics'
filtered_columns = [col for col in df.columns if string_to_match not in col]
df = df[filtered_columns]
string_to_match = 'Unnamed:'
filtered_columns = [col for col in df.columns if string_to_match not in col]
df = df[filtered_columns]
df_GE = df
df_GE
# Out:
#    original_firstorder_10Percentile  original_firstorder_90Percentile  \
# 0                           33278.0                           33547.0
# 0                           33274.0                           33546.0
# 0                           33278.0                           33548.0
# 0                           33275.6                           33544.0
# 0                           33277.0                           33549.0
# 0                           33274.6                           33545.0
# 0                           33278.0                           33549.0
# 0                           33271.0                           33544.4
# 0                           33278.0                           33550.4
# 0                           33272.6                           33543.0
#
#    original_firstorder_Energy  original_firstorder_Entropy  \
# 0                2.542216e+12                     4.109955
# 0                2.541904e+12                     4.136828
# ...

# %%
#Save the dataframe in a csv file
df_TO.to_csv('../../../../RadiomiK/Features_Positioning_test/TO_test/Final/Global/cyl0_glob.csv', index=False)
df_GE.to_csv('../../../../RadiomiK/Features_Positioning_test/GE_test/Final/Global/cyl0_glob.csv', index=False)

# %%
#add a column to the dataframe with the number of test that goes from 1 to 10
df_TO.insert(0, 'Test', range(1, 1 + len(df_TO)))
df_GE.insert(0, 'Test', range(1, 1 + len(df_GE)))

df_TO
# Out:
#    Test  original_firstorder_10Percentile  original_firstorder_90Percentile  \
# 0     1                           32264.6                           32529.0
# 0     2                           32262.0                           32529.0
# 0     3                           32263.0                           32529.0
# 0     4                           32265.6                           32527.4
# 0     5                           32263.6                           32530.0
# 0     6                           32265.0                           32525.0
# 0     7                           32264.0                           32530.0
# 0     8                           32262.0                           32525.4
# 0     9                           32262.0                           32530.0
# 0    10                           32265.6                           32524.0
#
#    original_firstorder_Energy  original_firstorder_Entropy  \
# 0                2.274147e+12                     4.074692
# ...

# %%
#Keep only the [1,87] columns of the dataframe
df_TO = df_TO.iloc[:, 1:87]
df_GE = df_GE.iloc[:, 1:87]

df_TO
# Out:
#    original_firstorder_10Percentile  original_firstorder_90Percentile  \
# 0                           32264.6                           32529.0
# 0                           32262.0                           32529.0
# 0                           32263.0                           32529.0
# 0                           32265.6                           32527.4
# 0                           32263.6                           32530.0
# 0                           32265.0                           32525.0
# 0                           32264.0                           32530.0
# 0                           32262.0                           32525.4
# 0                           32262.0                           32530.0
# 0                           32265.6                           32524.0
#
#    original_firstorder_Energy  original_firstorder_Entropy  \
# 0                2.274147e+12                     4.074692
# 0                2.273877e+12                     4.083260
# ...

# %%
#calculate the CV of each feature
cv_TO = df_TO.std() / df_TO.mean()
cv_GE = df_GE.std() / df_GE.mean()

#Create a dataframe with the CV of each feature with the name of the column "CV"
cv_TO = pd.DataFrame(cv_TO, columns=['CV'])
cv_GE = pd.DataFrame(cv_GE, columns=['CV'])

#add column with the name of the feature
cv_TO['Feature'] = cv_TO.index
cv_GE['Feature'] = cv_GE.index

#change the index of the dataframe
cv_TO = cv_TO.reset_index(drop=True)
cv_GE = cv_GE.reset_index(drop=True)

#Add a column Manufacturer with the name of the manufacturer
cv_TO['Manufacturer'] = 'Toshiba'
cv_GE['Manufacturer'] = 'GE'

#concatenate the two dataframe
cv = pd.concat([cv_TO, cv_GE])

#reset the index
cv = cv.reset_index(drop=True)


cv
# Out:
#            CV                                            Feature Manufacturer
# 0    0.000045                   original_firstorder_10Percentile      Toshiba
# 1    0.000070                   original_firstorder_90Percentile      Toshiba
# 2    0.000072                         original_firstorder_Energy      Toshiba
# 3    0.002907                        original_firstorder_Entropy      Toshiba
# 4    0.013933             original_firstorder_InterquartileRange      Toshiba
# ..        ...                                                ...          ...
# 167  0.076259  original_gldm_LargeDependenceLowGrayLevelEmphasis           GE
# 168  0.083833                 original_gldm_LowGrayLevelEmphasis           GE
# 169  0.011336              original_gldm_SmallDependenceEmphasis           GE
# 170  0.055800  original_gldm_SmallDependenceHighGrayLevelEmph...           GE
# 171  0.101055  original_gldm_SmallDependenceLowGrayLevelEmphasis           GE
#
# [172 rows x 3 columns]

# %%
#Get the features with CV > 0.10
cv_10 = cv[cv['CV'] > 0.10]

#reset the index
cv_10 = cv_10.reset_index(drop=True)

cv_10
# Out:
#          CV                                            Feature Manufacturer
# 0  0.606325                       original_firstorder_Skewness           GE
# 1  0.471656                         original_glcm_ClusterShade           GE
# 2  0.261450                          original_glcm_Correlation           GE
# 3  0.106563            original_glszm_LowGrayLevelZoneEmphasis           GE
# 4  0.115859       original_glszm_SmallAreaLowGrayLevelEmphasis           GE
# 5  0.101055  original_gldm_SmallDependenceLowGrayLevelEmphasis           GE

# %%
#Save the dataframe in a csv file
cv_10.to_csv('../../../../RadiomiK/Features_Positioning_test/Features_Not_repeatable/cv_Cyl0.csv', index=False)
